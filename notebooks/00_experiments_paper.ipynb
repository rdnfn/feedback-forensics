# %% [markdown]
# # Commands for re-running main experiments in paper
#
# To be run from home dir (not this notebook).

# %%
# Chatbot Arena experiments
# ! ff-annotate -d "data/paper/lmsys_arena_explorer_data_w_topics_2025-02-23_rand10k.csv" -m "openrouter/google/gemini-2.5-flash"

# %%
# ! ff-annotate -d "data/paper/multipref_gpt4_human_merged.csv" -m "openrouter/google/gemini-2.5-flash"

# %%
# ! ff-annotate -d "data/paper/prism_rand_incl_metadata_v2.csv" -m "openrouter/google/gemini-2.5-flash"

# %%
# ! ff-annotate -d "data/paper/llama4_exp_vs_public_vs_other_v2.csv" -m "openrouter/google/gemini-2.5-flash"

# %%
# data/paper/models_comparison_wo_annotations.json
# ff-annotate -d "data/paper/models_comparison_wo_annotations.json" -m "openrouter/google/gemini-2.5-flash"

# %%
# For continuing from a previous run
# icai-exp -cd exp/outputs/2025-09-24_20-52-56/.hydra/ prior_cache_path=exp/outputs/2025-09-24_20-52-56/
